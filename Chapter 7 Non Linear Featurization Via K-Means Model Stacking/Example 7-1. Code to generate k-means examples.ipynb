# %% [markdown]
# # Example 7-1. Code to generate k-means examples

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n_data=1000
seed = 1
n_clusters = 4

# %% [markdown]
# Generate random Guassian bloba and run k-Means

# %%
#blobs, blob_labels = make_blobs(n_samples = n_data, n_features =2, centers=n_centers, random_state= seed)
blobs, blob_labels = make_blobs(n_samples = n_data, n_features=2,  centers=n_centers, random_state=seed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e15abab7ef70> in <module>
#       1 #blobs, blob_labels = make_blobs(n_samples = n_data, n_features =2, centers=n_centers, random_state= seed)
# ----> 2 blobs, blob_labels = make_blobs(n_samples = n_data, n_features=2,  centers=n_center, random_state=seed)
#
# NameError: name 'n_center' is not defined

# %%
blobs, blob_labels = make_blobs(n_samples=n_data, n_features=2, 
                                centers=n_centers, random_state=seed)
clusters_blob = KMeans(n_clusters=n_centers, random_state=seed).fit_predict(blobs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9e336f2bba46> in <module>
#       1 blobs, blob_labels = make_blobs(n_samples=n_data, n_features=2,
# ----> 2                                 centers=n_centers, random_state=seed)
#       3 clusters_blob = KMeans(n_clusters=n_centers, random_state=seed).fit_predict(blobs)
#
# NameError: name 'n_centers' is not defined

# %%
n_data = 1000
seed = 1
n_centers = 4

# Generate random Gaussian blobs and run K-means
blobs, blob_labels = make_blobs(n_samples=n_data, n_features=2, 
                                centers=n_centers, random_state=seed)
clusters_blob = KMeans(n_clusters=n_centers, random_state=seed).fit_predict(blobs)

# Generate data uniformly at random and run K-means
uniform = np.random.rand(n_data, 2)
clusters_uniform = KMeans(n_clusters=n_centers, random_state=seed).fit_predict(uniform)

# %%
igure = plt.figure(figsize=(20,10))
plt.subplot(221)
plt.scatter(blobs[:, 0], blobs[:, 1], c=blob_labels, edgecolors='k', cmap='PuRd')
plt.title("(a) Four randomly generated blobs", fontsize=14)
plt.axis('off')

plt.subplot(222)
plt.scatter(blobs[:, 0], blobs[:, 1], c=clusters_blob, edgecolors='k', cmap='PuRd')
plt.title("(b) Clusters found via K-means", fontsize=14)
plt.axis('off')

plt.subplot(223)
plt.scatter(uniform[:, 0], uniform[:, 1], edgecolors='k')
plt.title("(c) 1000 randomly generated pois", fontsize=14)
plt.axis('off')

plt.subplot(224)
plt.scatter(uniform[:, 0], uniform[:, 1], c=clusters_uniform, edgecolors='k', cmap='PuRd')
plt.title("(d) Clusters found via K-means", fontsize=14)
plt.axis('off')
# Out:
# (-0.05633377047117758,
#  1.0557558100129465,
#  -0.06234067818209356,
#  1.0629570425528645)
